# %%
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# C:\Users\user\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
udemy = pd.read_csv('D:\\DATA_SET\\udemy_output_All_Finance__Accounting_p1_p626.csv')
udemy
# Out:
#             id                                              title  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3       648826         The Complete Financial Analyst Course 2020
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...
# ...        ...                                                ...
# 13603  3005408                      מושגים בסיסיים באופציות חלק ב
# 13604  3467284                            Programa de Integridade
# 13605  3368222  Goodwill and Method of Calculating Goodwill (A...
# 13606  3211345                                Poderoso Investidor
# 13607  2935720         Acabou a Previdência e agora? -  Volume 03
#
#                                                      url  is_paid  \
# 0                     /course/the-complete-sql-bootcamp/     True
# ...

# %%
udemy.columns
# Out:
# Index(['id', 'title', 'url', 'is_paid', 'num_subscribers', 'avg_rating',
#        'avg_rating_recent', 'rating', 'num_reviews', 'is_wishlisted',
#        'num_published_lectures', 'num_published_practice_tests', 'created',
#        'published_time', 'discount_price__amount', 'discount_price__currency',
#        'discount_price__price_string', 'price_detail__amount',
#        'price_detail__currency', 'price_detail__price_string'],
#       dtype='object')

# %% [markdown]
# Data Cleaning and Processing

# %%
udemy['id'].unique().size
# Out:
# 13608

# %%
udemy.describe(include='all')
# Out:
#                   id                                              title  \
# count   1.360800e+04                                              13608
# unique           NaN                                              13563
# top              NaN  Shopify Dropshipping - Scale to 7 figures with...
# freq             NaN                                                  2
# mean    1.681721e+06                                                NaN
# std     9.539271e+05                                                NaN
# min     2.762000e+03                                                NaN
# 25%     8.580862e+05                                                NaN
# 50%     1.623421e+06                                                NaN
# 75%     2.503720e+06                                                NaN
# max     3.486006e+06                                                NaN
#
#                                        url is_paid  num_subscribers  \
# ...

# %%
udemy['published_time']
# Out:
# 0        2016-04-06T05:16:11Z
# 1        2016-08-23T16:59:49Z
# 2        2017-11-14T23:58:14Z
# 3        2016-01-21T01:38:48Z
# 4        2016-01-11T21:39:33Z
#                  ...
# 13603    2020-04-23T02:06:55Z
# 13604    2020-09-03T15:26:47Z
# 13605    2020-07-31T12:14:40Z
# 13606    2020-07-15T10:35:38Z
# 13607    2020-04-02T16:33:32Z
# Name: published_time, Length: 13608, dtype: object

# %%
udemy['num_published_practice_tests'].value_counts()
# Out:
# num_published_practice_tests
# 0    13008
# 2      214
# 1      202
# 6       67
# 5       43
# 3       39
# 4       35
# Name: count, dtype: int64

# %%
original_df = udemy.copy()
all_columns_dataset=udemy.copy()

# %%
all_columns_dataset
# Out:
#             id                                              title  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3       648826         The Complete Financial Analyst Course 2020
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...
# ...        ...                                                ...
# 13603  3005408                      מושגים בסיסיים באופציות חלק ב
# 13604  3467284                            Programa de Integridade
# 13605  3368222  Goodwill and Method of Calculating Goodwill (A...
# 13606  3211345                                Poderoso Investidor
# 13607  2935720         Acabou a Previdência e agora? -  Volume 03
#
#                                                      url  is_paid  \
# 0                     /course/the-complete-sql-bootcamp/     True
# ...

# %%
udemy = udemy.drop(columns=['id',
'title',
'url',
'is_wishlisted',
'created',
'published_time',
'num_published_practice_tests'])

# %%
udemy.head()
# Out:
#    is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 0     True           295509     4.66019            4.67874  4.67874
# 1     True           209070     4.58956            4.60015  4.60015
# 2     True           155282     4.59491            4.59326  4.59326
# 3     True           245860     4.54407            4.53772  4.53772
# 4     True           374836     4.47080            4.47173  4.47173
#
#    num_reviews  num_published_lectures  discount_price__amount  \
# 0        78006                      84                   455.0
# 1        54581                      78                   455.0
# 2        52653                     292                   455.0
# 3        46447                     338                   455.0
# 4        41630                      83                   455.0
#
#   discount_price__currency discount_price__price_string  price_detail__amount  \
# 0                      INR                         ₹455                8640.0
# ...

# %%
udemy[(udemy['num_reviews']) > (udemy['num_subscribers'])]
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 10898     True                0        3.00            3.00000  3.00000
# 10950     True                0        5.00            5.00000  5.00000
# 12905     True                0        2.75            3.19403  3.19403
# 12942     True                1        2.50            2.50000  2.50000
# 13049     True                0        5.00            5.00000  5.00000
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# 10898            1                      12                   455.0
# 10950            1                       0                     NaN
# 12905            2                       0                   455.0
# 12942            2                       8                     NaN
# 13049            1                      13                     NaN
#
#       discount_price__currency discount_price__price_string  \
# 10898                      INR                         ₹455
# ...

# %%
udemy.iloc[65]
# Out:
# is_paid                            True
# num_subscribers                   36650
# avg_rating                      4.54274
# avg_rating_recent               4.55138
# rating                          4.55138
# num_reviews                        5893
# num_published_lectures               43
# discount_price__amount            455.0
# discount_price__currency            INR
# discount_price__price_string       ₹455
# price_detail__amount             8640.0
# price_detail__currency              INR
# price_detail__price_string       ₹8,640
# Name: 65, dtype: object

# %%
reviews_subscribers = (udemy['num_reviews']) > (udemy['num_subscribers'])
reviews_subscribers.sum()
# Out:
# 5

# %%
udemy[reviews_subscribers]
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 10898     True                0        3.00            3.00000  3.00000
# 10950     True                0        5.00            5.00000  5.00000
# 12905     True                0        2.75            3.19403  3.19403
# 12942     True                1        2.50            2.50000  2.50000
# 13049     True                0        5.00            5.00000  5.00000
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# 10898            1                      12                   455.0
# 10950            1                       0                     NaN
# 12905            2                       0                   455.0
# 12942            2                       8                     NaN
# 13049            1                      13                     NaN
#
#       discount_price__currency discount_price__price_string  \
# 10898                      INR                         ₹455
# ...

# %%
index_list = udemy[reviews_subscribers].index
udemy = udemy.drop(index=index_list)
all_columns_dataset = all_columns_dataset.drop(index=index_list)

# %%
udemy=udemy.reset_index(drop=True) #check why we are passing this drop arguement
all_columns_dataset=all_columns_dataset.reset_index()

# %%
udemy
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 0         True           295509     4.66019            4.67874  4.67874
# 1         True           209070     4.58956            4.60015  4.60015
# 2         True           155282     4.59491            4.59326  4.59326
# 3         True           245860     4.54407            4.53772  4.53772
# 4         True           374836     4.47080            4.47173  4.47173
# ...        ...              ...         ...                ...      ...
# 13598    False               47     0.00000            0.00000  0.00000
# 13599    False               19     0.00000            0.00000  0.00000
# 13600    False               47     0.00000            0.00000  0.00000
# 13601    False               48     0.00000            0.00000  0.00000
# 13602     True                0     0.00000            0.00000  0.00000
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# ...

# %%
reviews_subscribers = (udemy['num_reviews']) > (udemy['num_subscribers'])
reviews_subscribers.sum()
# Out:
# 0

# %%
#price related columns
price_related_columns =['discount_price__amount', 'discount_price__currency',
       'discount_price__price_string', 'price_detail__amount',
       'price_detail__currency', 'price_detail__price_string']

# %%
price_related_columns
# Out:
# ['discount_price__amount',
#  'discount_price__currency',
#  'discount_price__price_string',
#  'price_detail__amount',
#  'price_detail__currency',
#  'price_detail__price_string']

# %%
udemy[price_related_columns].sample(10)
# Out:
#        discount_price__amount discount_price__currency  \
# 4566                      NaN                      NaN
# 9868                    455.0                      INR
# 7998                    455.0                      INR
# 7199                    455.0                      INR
# 1958                    455.0                      INR
# 6899                    455.0                      INR
# 12029                     NaN                      NaN
# 7969                    455.0                      INR
# 5938                    455.0                      INR
# 5499                      NaN                      NaN
#
#       discount_price__price_string  price_detail__amount  \
# 4566                           NaN                5120.0
# 9868                          ₹455                8640.0
# 7998                          ₹455                6400.0
# 7199                          ₹455                8640.0
# 1958                          ₹455                1280.0
# ...

# %%
udemy[['discount_price__currency',"price_detail__currency"]].describe()
# Out:
#        discount_price__currency price_detail__currency
# count                     12203                  13106
# unique                        1                      1
# top                         INR                    INR
# freq                      12203                  13106

# %%
udemy.discount_price__amount.value_counts()
# Out:
# discount_price__amount
# 455.0     11408
# 468.0       135
# 700.0        86
# 3200.0       61
# 462.0        47
# 481.0        44
# 800.0        39
# 520.0        34
# 474.0        30
# 1600.0       27
# 488.0        27
# 640.0        24
# 494.0        22
# 480.0        17
# 2400.0       16
# 960.0        13
# 720.0        12
# 1440.0       11
# 2880.0       10
# 2080.0        9
# 1920.0        8
# 1520.0        8
# 1200.0        8
# 500.0         7
# 1120.0        7
# 2240.0        7
# 1280.0        6
# 514.0         6
# 2720.0        6
# 507.0         5
# 2000.0        5
# 560.0         5
# 2160.0        5
# 1360.0        5
# 1040.0        5
# 1760.0        4
# 1680.0        3
# 880.0         3
# 3040.0        3
# 2800.0        3
# 2640.0        2
# 2960.0        2
# 2560.0        2
# 3120.0        2
# 2320.0        2
# 552.0         2
# 533.0         2
# 546.0         2
# 540.0         2
# 1840.0        1
# 760.0         1
# 2480.0        1
# 611.0         1
# ...

# %%
demy=udemy.drop(columns=['discount_price__price_string','price_detail__price_string','discount_price__currency','price_detail__currency'])

# %%
udemy.head(3)
# Out:
#    is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 0     True           295509     4.66019            4.67874  4.67874
# 1     True           209070     4.58956            4.60015  4.60015
# 2     True           155282     4.59491            4.59326  4.59326
#
#    num_reviews  num_published_lectures  discount_price__amount  \
# 0        78006                      84                   455.0
# 1        54581                      78                   455.0
# 2        52653                     292                   455.0
#
#   discount_price__currency discount_price__price_string  price_detail__amount  \
# 0                      INR                         ₹455                8640.0
# 1                      INR                         ₹455                8640.0
# 2                      INR                         ₹455                8640.0
#
#   price_detail__currency price_detail__price_string
# 0                    INR                     ₹8,640
# ...

# %%
price_related_columns = ['discount_price__amount','price_detail__amount']

# %%
udemy['discount_price__amount']
# Out:
# 0        455.0
# 1        455.0
# 2        455.0
# 3        455.0
# 4        455.0
#          ...
# 13598      NaN
# 13599      NaN
# 13600      NaN
# 13601      NaN
# 13602      NaN
# Name: discount_price__amount, Length: 13603, dtype: float64

# %%
#Retrieving instances where the values are not 455 and Nan

udemy['discount_price__amount'].notna()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 13598    False
# 13599    False
# 13600    False
# 13601    False
# 13602    False
# Name: discount_price__amount, Length: 13603, dtype: bool

# %%
series_bool_discount_price=(udemy['discount_price__amount'] !=455) & (udemy['discount_price__amount'].notna())

# %%
not_455_not_na = series_bool_discount_price.sum()
not_455_not_na
# Out:
# 795

# %%
series_bool_discount_price
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13598    False
# 13599    False
# 13600    False
# 13601    False
# 13602    False
# Name: discount_price__amount, Length: 13603, dtype: bool

# %%
#checking the percentage of discount price rows that are not equal to 455 not Nan
not_455_not_na_percentage = (not_455_not_na/udemy['discount_price__amount'].size)*100
np.around(not_455_not_na_percentage,2)
# Out:
# 5.84

# %%
#Examining price_detail__amount

# %%
def_price_and_is_paid=udemy[['price_detail__amount','is_paid']]

# %%
def_price_and_is_paid
# Out:
#        price_detail__amount  is_paid
# 0                    8640.0     True
# 1                    8640.0     True
# 2                    8640.0     True
# 3                    8640.0     True
# 4                    8640.0     True
# ...                     ...      ...
# 13598                   NaN    False
# 13599                   NaN    False
# 13600                   NaN    False
# 13601                   NaN    False
# 13602                   NaN     True
#
# [13603 rows x 2 columns]

# %%
def_price_and_is_paid[def_price_and_is_paid['is_paid']==False].sample(5)
# Out:
#        price_detail__amount  is_paid
# 13440                   NaN    False
# 13426                   NaN    False
# 13430                   NaN    False
# 13517                   NaN    False
# 11724                   NaN    False

# %%
def_price_and_is_paid[def_price_and_is_paid['is_paid']==True].sample(5)
# Out:
#        price_detail__amount  is_paid
# 8305                 1920.0     True
# 10440                8640.0     True
# 12820                3520.0     True
# 4016                 1600.0     True
# 5300                 1280.0     True

# %%
#checking is there any data point with any price when the course is free 
((def_price_and_is_paid['is_paid']==False) & (def_price_and_is_paid['price_detail__amount'].notna())).sum()
# Out:
# 0

# %%
#checking is there any data point with price NAN when the course is paid 
((def_price_and_is_paid['is_paid']==True) & (def_price_and_is_paid['price_detail__amount'].isna())).sum()
# Out:
# 1

# %%
#checking for the invalid data point
udemy[(udemy['is_paid']==True) & (udemy['price_detail__amount'].isna())]
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent  rating  \
# 13602     True                0         0.0                0.0     0.0
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# 13602            0                      14                     NaN
#
#       discount_price__currency discount_price__price_string  \
# 13602                      NaN                          NaN
#
#        price_detail__amount price_detail__currency price_detail__price_string
# 13602                   NaN                    NaN                        NaN

# %%
udemy[(udemy['is_paid']==True) & (udemy['price_detail__amount'].isna())]
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent  rating  \
# 13602     True                0         0.0                0.0     0.0
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# 13602            0                      14                     NaN
#
#       discount_price__currency discount_price__price_string  \
# 13602                      NaN                          NaN
#
#        price_detail__amount price_detail__currency price_detail__price_string
# 13602                   NaN                    NaN                        NaN

# %%
#resetting index
udemy.reset_index(inplace=True,drop=True)
all_columns_dataset.reset_index(inplace=True,drop=True)

# %%
#now we can replace all Nan values into zero

udemy['price_detail__amount'] = udemy['price_detail__amount'].fillna(0)

# %%
udemy['price_detail__amount'].isnull().sum()
# Out:
# 0

# %%
udemy['price_detail__amount'].value_counts()
# Out:
# price_detail__amount
# 8640.0     3213
# 1280.0     3031
# 3200.0     1033
# 6400.0      984
# 1600.0      776
# 1920.0      689
# 0.0         497
# 2560.0      451
# 2240.0      405
# 6080.0      285
# 4800.0      251
# 2880.0      241
# 5120.0      183
# 3840.0      182
# 5760.0      166
# 4480.0      154
# 8000.0      142
# 3520.0      125
# 12800.0     122
# 7680.0       94
# 4160.0       93
# 8320.0       71
# 5440.0       67
# 6720.0       67
# 7040.0       62
# 9600.0       52
# 8960.0       52
# 7360.0       41
# 9280.0       34
# 10240.0       8
# 12480.0       8
# 11840.0       6
# 12160.0       4
# 11520.0       4
# 9920.0        3
# 11200.0       3
# 10560.0       2
# 10880.0       2
# Name: count, dtype: int64

# %%
udemy.isnull().sum()
# Out:
# is_paid                            0
# num_subscribers                    0
# avg_rating                         0
# avg_rating_recent                  0
# rating                             0
# num_reviews                        0
# num_published_lectures             0
# discount_price__amount          1400
# discount_price__currency        1400
# discount_price__price_string    1400
# price_detail__amount               0
# price_detail__currency           497
# price_detail__price_string       497
# dtype: int64

# %%
udemy
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 0         True           295509     4.66019            4.67874  4.67874
# 1         True           209070     4.58956            4.60015  4.60015
# 2         True           155282     4.59491            4.59326  4.59326
# 3         True           245860     4.54407            4.53772  4.53772
# 4         True           374836     4.47080            4.47173  4.47173
# ...        ...              ...         ...                ...      ...
# 13598    False               47     0.00000            0.00000  0.00000
# 13599    False               19     0.00000            0.00000  0.00000
# 13600    False               47     0.00000            0.00000  0.00000
# 13601    False               48     0.00000            0.00000  0.00000
# 13602     True                0     0.00000            0.00000  0.00000
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# ...

# %%
udemy=udemy.rename(columns={"price_detail__amount":'price'})

# %%
udemy.columns
# Out:
# Index(['is_paid', 'num_subscribers', 'avg_rating', 'avg_rating_recent',
#        'rating', 'num_reviews', 'num_published_lectures',
#        'discount_price__amount', 'discount_price__currency',
#        'discount_price__price_string', 'price', 'price_detail__currency',
#        'price_detail__price_string'],
#       dtype='object')

# %%
((udemy['price'] > 1500) & (udemy['price'] < 2000)).sum()
# Out:
# 1465

# %%
import matplotlib.pyplot as plt

# %%
#checking for outliers
sns.boxplot(x=udemy['price'])
plt.show()

# %%
udemy[['rating','avg_rating','avg_rating_recent']].sample(10)
# Out:
#         rating  avg_rating  avg_rating_recent
# 627    4.39341     4.38889            4.39341
# 9680   4.46681     4.25926            4.46681
# 5682   4.12490     4.05000            4.12490
# 665    4.39228     4.31579            4.39228
# 1894   4.14583     4.14000            4.14583
# 2784   4.39930     4.33333            4.39930
# 1264   4.16015     4.15476            4.16015
# 367    4.42610     4.45430            4.42610
# 8424   4.27654     4.25000            4.27654
# 12294  3.60533     3.63636            3.60533

# %%
from scipy import stats

# %%
#let's findout correlation between 'avg_rating' and  'avg_rating_recent'
correlation_coefficient = stats.pearsonr(udemy['avg_rating'],udemy['avg_rating_recent'])[0]
np.around(correlation_coefficient,2)
# Out:
# 0.99

# %%
#Bivariate Analysis

# %%
# Filter data for paid and free courses
paid_courses = udemy[udemy['is_paid'] == True]
free_courses = udemy[udemy['is_paid'] == False]

# %%
paid_courses
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 0         True           295509     4.66019            4.67874  4.67874
# 1         True           209070     4.58956            4.60015  4.60015
# 2         True           155282     4.59491            4.59326  4.59326
# 3         True           245860     4.54407            4.53772  4.53772
# 4         True           374836     4.47080            4.47173  4.47173
# ...        ...              ...         ...                ...      ...
# 13384     True                4     0.00000            0.00000  0.00000
# 13385     True                2     0.00000            0.00000  0.00000
# 13386     True                0     0.00000            0.00000  0.00000
# 13387     True                1     0.00000            0.00000  0.00000
# 13602     True                0     0.00000            0.00000  0.00000
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# ...

# %%
free_courses
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 11482    False           259888     4.34928            4.35902  4.35902
# 11483    False           105131     4.20109            4.23170  4.23170
# 11484    False            43396     4.42509            4.43953  4.43953
# 11485    False            43106     4.30682            4.33887  4.33887
# 11486    False            56172     4.15925            4.20690  4.20690
# ...        ...              ...         ...                ...      ...
# 13597    False               19     0.00000            0.00000  0.00000
# 13598    False               47     0.00000            0.00000  0.00000
# 13599    False               19     0.00000            0.00000  0.00000
# 13600    False               47     0.00000            0.00000  0.00000
# 13601    False               48     0.00000            0.00000  0.00000
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# ...

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))

# Scatter plot for average rating vs. number of reviews
plt.scatter(udemy['avg_rating'], udemy['num_reviews'], alpha=0.5, color='blue')

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))

# Scatter plot for discount price vs. number of published lectures
plt.scatter(udemy['discount_price__amount'], udemy['num_published_lectures'], alpha=0.5, color='green')
# Set labels and title
plt.title('Discount Price vs. Number of Published Lectures')
plt.xlabel('Discount Price')
plt.ylabel('Number of Published Lectures')

# Show the plot
plt.show()

# %%
#cting_only_numerical columns for the correlation matrix
numerical_columns = udemy.select_dtypes(include=['float64', 'int64']).columns

# %%
# Calculating the correlation matrix
correlation_matrix = udemy[numerical_columns].corr()

# %%
# Creating a heatmap for visualization
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)

# Set title
plt.title('Correlation Matrix')

# Show the plot
plt.show()
